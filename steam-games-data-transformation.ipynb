# %% [markdown]
# Original Author: [Kaggle](https://www.kaggle.com/code/terencicp/steam-games-data-transformation/notebook)
#
# 1. Steam Games Dataset by Martin Bustos
# 2. Video Games on Steam by Sujay Kapadnis

# %%
import pandas as pd
import json
import numpy as np

# %% [markdown]
# And load the first file:

# %%
first_file = 'games.json'
with open(first_file, 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# %% [markdown]
# I'll convert the JSON into a DataFrame, ignoring the variables I won't analyze:

# %%
# Variables I won't analyze
unnecessary_vars = [
    'packages', 'screenshots', 'movies', 'score_rank', 'header_image',
    'reviews', 'website', 'support_url', 'notes', 'support_email',
    'recommendations', 'user_score', 'median_playtime_forever',
    'median_playtime_2weeks', 'required_age', 'metacritic_score',
    'metacritic_url', 'peak_ccu', 'detailed_description', 'about_the_game',
    'windows', 'mac', 'linux', 'achievements', 'full_audio_languages',
    'genres', 'dlc_count', 'supported_languages', 'developers',
    'publishers', 'average_playtime_forever', 'average_playtime_2weeks'
]

# %%
# Process each game's information and store in a list
games = [{
    **{k: v for k, v in game_info.items() if k not in unnecessary_vars},
    'tags': list(tags.keys()) if isinstance((tags := game_info.get('tags', {})), dict) else [],
    'tag_frequencies': list(tags.values()) if isinstance(tags, dict) else [],
    'app_id': app_id
} for app_id, game_info in json_data.items()]

# Create a DataFrame from the processed list
df = pd.DataFrame(games)

# %% [markdown]
# Let's have a look at the DataFrame:

# %%
df
# Out:
#                                   name release_date  price  \
# 0                     Counter-Strike 2   2012-08-21   0.00
# 1                  PUBG: BATTLEGROUNDS   2017-12-21   0.00
# 2                               Dota 2   2013-07-09   0.00
# 3                   Grand Theft Auto V   2015-04-13   0.00
# 4      Tom Clancy's Rainbow Six® Siege   2015-12-01  19.99
# ...                                ...          ...    ...
# 83641                  Circuit Breaker   2021-10-21   4.99
# 83642                    Chess vs Chat   2022-08-09   3.99
# 83643                        Orbtangle   2022-10-28   1.99
# 83644                       Flashlight   2021-10-25   2.99
# 83645                         Wonfourn   2018-06-15   5.99
#
#                                        short_description  \
# 0      For over two decades, Counter-Strike has offer...
# 1      Play PUBG: BATTLEGROUNDS for free. Land on str...
# 2      Every day, millions of players worldwide enter...
# 3      Grand Theft Auto V for PC offers players the o...
# 4      Tom Clancy's Rainbow Six® Siege is an elite, t...
# ...                                                  ...
# 83641  In the cyber-future of 2009, the most popular ...
# 83642  Allow your chatters to actively participate an...
# 83643  Orbtangle is a simplistic puzzle game which re...
# 83644  Salvage scrap, build defenses, and rank-up to ...
# 83645  Wonfourn challenges you to fulfill your destin...
#
#                                               categories  positive  negative  \
# 0      [['Multi-player', 'Cross-Platform Multiplayer'...   7024836   1029779
# 1      [['Multi-player', 'PvP', 'Online PvP', 'Stats'...   1379580    981860
# 2      [['Multi-player', 'Co-op', 'Steam Trading Card...   1832477    406030
# 3      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1557234    236827
# 4      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1094330    190046
# ...                                                  ...       ...       ...
# 83641              [['Single-player', 'Family Sharing']]         1         0
# 83642  [['Single-player', 'Multi-player', 'PvP', 'Onl...         2         1
# 83643  [['Single-player', 'Steam Achievements', 'Fami...         5         0
# 83644  [['Single-player', 'Multi-player', 'PvP', 'Onl...         3         0
# 83645  [['Single-player', 'Tracked Controller Support...         2        11
#
#             estimated_owners  \
# 0      100000000 - 200000000
# 1       50000000 - 100000000
# 2      200000000 - 500000000
# 3       50000000 - 100000000
# 4        20000000 - 50000000
# ...                      ...
# 83641              0 - 20000
# 83642              0 - 20000
# 83643              0 - 20000
# 83644              0 - 20000
# 83645              0 - 20000
#
#                                                     tags  \
# 0      [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1      [Survival, Shooter, Battle Royale, Multiplayer...
# 2      [Free to Play, MOBA, Multiplayer, Strategy, e-...
# 3      [Open World, Action, Multiplayer, Crime, Autom...
# 4      [FPS, PvP, e-sports, Multiplayer, Tactical, Sh...
# ...                                                  ...
# 83641  [Strategy, Casual, PvE, Singleplayer, Tactical...
# 83642  [Indie, Strategy, Puzzle, Multiplayer, 2D, Che...
# 83643  [Puzzle, Colorful, Relaxing, Logic, Minimalist...
# 83644  [Top-Down Shooter, Rogue-lite, Action Roguelik...
# 83645  [Action, Indie, Violent, Strategy, Adventure, VR]
#
#                                          tag_frequencies   app_id
# 0      [90076, 64786, 61798, 52887, 47165, 46061, 431...      730
# 1      [14611, 12477, 10683, 10648, 8242, 7598, 7202,...   578080
# 2      [59559, 19966, 15153, 14096, 11631, 10822, 816...      570
# 3      [31998, 23177, 21328, 19059, 18579, 18412, 180...   271590
# 4      [9689, 9073, 9026, 8948, 8948, 8944, 8901, 888...   359550
# ...                                                  ...      ...
# 83641  [72, 48, 47, 44, 41, 37, 32, 29, 27, 25, 22, 2...  1745960
# 83642                   [31, 21, 11, 11, 11, 11, 11, 11]  1888920
# 83643  [54, 46, 44, 41, 38, 33, 30, 27, 25, 24, 22, 2...  2166420
# 83644  [138, 132, 128, 125, 121, 116, 108, 107, 104, ...  1456260
# 83645                           [22, 20, 20, 19, 19, 10]   655980
#
# [83646 rows x 11 columns]

# %% [markdown]
# ## Data Cleaning
#
# Great! We've got the data we need, but it seems we have more rows than there are games on Steam. Let's see how many games have no sales:

# %%
count = (df['estimated_owners'] == "0 - 0").sum()
print("Number of games with estimated owners '0 - 0':", count)
# Out:
# Number of games with estimated owners '0 - 0': 6573

# %%
df[df['estimated_owners'] == "0 - 0"]
# Out:
#                                name release_date  price  \
# 44                     Overwatch® 2   2023-08-10   0.00
# 102                      THE FINALS   2023-12-07   0.00
# 104                            Muck   2021-06-05   0.00
# 114                       Crab Game   2021-10-29   0.00
# 169    MultiVersus – Technical Test   2022-05-16   0.00
# ...                             ...          ...    ...
# 83568       Neon Fantasy: Predators   2023-12-14   1.99
# 83589                    MetaStrike   2024-04-22   0.00
# 83594                      Klaystar   2022-09-16   0.00
# 83598                临   第一部分“假作真”篇   2023-07-02   0.00
# 83619                   Run On Home   2023-03-21   0.00
#
#                                        short_description  \
# 44     Overwatch 2 is a critically acclaimed, team-ba...
# 102    Join THE FINALS, the world-famous, free-to-pla...
# 104    Muck is a survival-roguelike. Collect resource...
# 114    Crab Game is a First-Person Multiplayer game w...
# 169
# ...                                                  ...
# 83568  Neon Fantasy: Predators is the perfect puzzle ...
# 83589  MetaStrike is a first-person game, multiplayer...
# 83594  Klaystar is a 2D precision platformer, where t...
# 83598  'CONFRONTING'is a science fiction micro horror...
# 83619  A short horror/comedy themed 2.5D platformer w...
#
#                                               categories  positive  negative  \
# 44     [['Multi-player', 'PvP', 'Online PvP', 'Co-op'...         0         0
# 102    [['Multi-player', 'PvP', 'Online PvP', 'Co-op'...         0         0
# 104    [['Single-player', 'Multi-player', 'PvP', 'Onl...         0         0
# 114    [['Multi-player', 'PvP', 'Online PvP', 'Co-op'...         0         0
# 169                                                 [[]]         0         0
# ...                                                  ...       ...       ...
# 83568  [['Single-player', 'Steam Achievements', 'Stea...         0         0
# 83589  [['Single-player', 'Multi-player', 'PvP', 'Onl...         0         0
# 83594                                [['Single-player']]         0         0
# 83598                                [['Single-player']]         0         0
# 83619          [['Single-player', 'Steam Achievements']]         0         0
#
#       estimated_owners tags tag_frequencies   app_id
# 44               0 - 0   []              []  2357570
# 102              0 - 0   []              []  2073850
# 104              0 - 0   []              []  1625450
# 114              0 - 0   []              []  1782210
# 169              0 - 0   []              []  1829770
# ...                ...  ...             ...      ...
# 83568            0 - 0   []              []  2717240
# 83589            0 - 0   []              []  2476720
# 83594            0 - 0   []              []  2091880
# 83598            0 - 0   []              []  1565110
# 83619            0 - 0   []              []  2330140
#
# [6573 rows x 11 columns]

# %% [markdown]
# Some games just seem to be developer tests. Let's remove them. We'll also remove games with no reviews or no categories:

# %%
# Filter games without sales, reviews or categories
df2 = df[~((df['estimated_owners'] == "0 - 0") | (df['positive'] + df['negative'] == 0) | (df['categories'].str.len() == 0))]

# %% [markdown]
# To keep things simple, I'll also remove games older than 2013, since there are very few games more than 10 year old on Steam:

# %%
# Filter games released before 2013
df2 = df2.copy()
df2['release_date'] = pd.to_datetime(df2['release_date'], format='mixed')
df2 = df2[df2['release_date'].dt.year >= 2013]

# %% [markdown]
# Let's see the DataFrame again. It seems we got rid of more than 20000 irrelevant games:

# %%
df2
# Out:
#                                   name release_date  price  \
# 1                  PUBG: BATTLEGROUNDS   2017-12-21   0.00
# 2                               Dota 2   2013-07-09   0.00
# 3                   Grand Theft Auto V   2015-04-13   0.00
# 4      Tom Clancy's Rainbow Six® Siege   2015-12-01  19.99
# 8                                 Rust   2018-02-08  39.99
# ...                                ...          ...    ...
# 83641                  Circuit Breaker   2021-10-21   4.99
# 83642                    Chess vs Chat   2022-08-09   3.99
# 83643                        Orbtangle   2022-10-28   1.99
# 83644                       Flashlight   2021-10-25   2.99
# 83645                         Wonfourn   2018-06-15   5.99
#
#                                        short_description  \
# 1      Play PUBG: BATTLEGROUNDS for free. Land on str...
# 2      Every day, millions of players worldwide enter...
# 3      Grand Theft Auto V for PC offers players the o...
# 4      Tom Clancy's Rainbow Six® Siege is an elite, t...
# 8      The only aim in Rust is to survive. Everything...
# ...                                                  ...
# 83641  In the cyber-future of 2009, the most popular ...
# 83642  Allow your chatters to actively participate an...
# 83643  Orbtangle is a simplistic puzzle game which re...
# 83644  Salvage scrap, build defenses, and rank-up to ...
# 83645  Wonfourn challenges you to fulfill your destin...
#
#                                               categories  positive  negative  \
# 1      [['Multi-player', 'PvP', 'Online PvP', 'Stats'...   1379580    981860
# 2      [['Multi-player', 'Co-op', 'Steam Trading Card...   1832477    406030
# 3      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1557234    236827
# 4      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1094330    190046
# 8      [['Multi-player', 'MMO', 'PvP', 'Online PvP', ...    922081    136729
# ...                                                  ...       ...       ...
# 83641              [['Single-player', 'Family Sharing']]         1         0
# 83642  [['Single-player', 'Multi-player', 'PvP', 'Onl...         2         1
# 83643  [['Single-player', 'Steam Achievements', 'Fami...         5         0
# 83644  [['Single-player', 'Multi-player', 'PvP', 'Onl...         3         0
# 83645  [['Single-player', 'Tracked Controller Support...         2        11
#
#             estimated_owners  \
# 1       50000000 - 100000000
# 2      200000000 - 500000000
# 3       50000000 - 100000000
# 4        20000000 - 50000000
# 8       50000000 - 100000000
# ...                      ...
# 83641              0 - 20000
# 83642              0 - 20000
# 83643              0 - 20000
# 83644              0 - 20000
# 83645              0 - 20000
#
#                                                     tags  \
# 1      [Survival, Shooter, Battle Royale, Multiplayer...
# 2      [Free to Play, MOBA, Multiplayer, Strategy, e-...
# 3      [Open World, Action, Multiplayer, Crime, Autom...
# 4      [FPS, PvP, e-sports, Multiplayer, Tactical, Sh...
# 8      [Survival, Crafting, Multiplayer, Open World, ...
# ...                                                  ...
# 83641  [Strategy, Casual, PvE, Singleplayer, Tactical...
# 83642  [Indie, Strategy, Puzzle, Multiplayer, 2D, Che...
# 83643  [Puzzle, Colorful, Relaxing, Logic, Minimalist...
# 83644  [Top-Down Shooter, Rogue-lite, Action Roguelik...
# 83645  [Action, Indie, Violent, Strategy, Adventure, VR]
#
#                                          tag_frequencies   app_id
# 1      [14611, 12477, 10683, 10648, 8242, 7598, 7202,...   578080
# 2      [59559, 19966, 15153, 14096, 11631, 10822, 816...      570
# 3      [31998, 23177, 21328, 19059, 18579, 18412, 180...   271590
# 4      [9689, 9073, 9026, 8948, 8948, 8944, 8901, 888...   359550
# 8      [17867, 11333, 11263, 10699, 8363, 7973, 7266,...   252490
# ...                                                  ...      ...
# 83641  [72, 48, 47, 44, 41, 37, 32, 29, 27, 25, 22, 2...  1745960
# 83642                   [31, 21, 11, 11, 11, 11, 11, 11]  1888920
# 83643  [54, 46, 44, 41, 38, 33, 30, 27, 25, 24, 22, 2...  2166420
# 83644  [138, 132, 128, 125, 121, 116, 108, 107, 104, ...  1456260
# 83645                           [22, 20, 20, 19, 19, 10]   655980
#
# [68206 rows x 11 columns]

# %% [markdown]
# I'll also split the 'estimated_owners' column into two different variables, this way we'll be able to use it for aggregation in Tableau:

# %%
# Split estimated_owners into two: min_owners and max_owners
df2[['min_owners', 'max_owners']] = df2['estimated_owners'].str.split(' - ', expand=True)

# Remove the original field
df2 = df2.drop('estimated_owners', axis=1)

# %%
df2[['min_owners', 'max_owners']]
# Out:
#       min_owners max_owners
# 1       50000000  100000000
# 2      200000000  500000000
# 3       50000000  100000000
# 4       20000000   50000000
# 8       50000000  100000000
# ...          ...        ...
# 83641          0      20000
# 83642          0      20000
# 83643          0      20000
# 83644          0      20000
# 83645          0      20000
#
# [68206 rows x 2 columns]

# %% [markdown]
# Let's have a look at the distribution of prices:

# %%
# Box plot of price
df2.boxplot(column=['price'])
# Out:
# <Axes: >

# %%
# Games priced above 200$
df2[df2['price'] > 200]
# Out:
#                                     name release_date   price  \
# 51271              Aartform Curvy 3D 3.0   2013-11-12  299.90
# 58416  Ascent Free-Roaming VR Experience   2019-12-27  999.00
# 64554                      Houdini Indie   2018-10-10  269.99
# 73341        VEGAS Edit 20 Steam Edition   2022-11-01  249.00
# 78274      3DF Zephyr Lite Steam Edition   2016-02-02  249.00
# 78722              Aartform Curvy 3D 4.0   2020-01-20  299.99
#
#                                        short_description  \
# 51271  Curvy 3D 3.0 is an innovative sculpting progra...
# 58416  A premium highly-immersive VR experience devel...
# 64554  Houdini Indie's procedural node-based workflow...
# 73341  VEGAS Edit 20 Steam Edition. Fast, easy editin...
# 78274  3DF Zephyr allows you to automatically and eas...
# 78722  Curvy 3D 4.0 is an innovative sculpting progra...
#
#                                               categories  positive  negative  \
# 51271                                [['Single-player']]        32        13
# 58416  [['Single-player', 'Multi-player', 'Co-op', 'L...         6         1
# 64554    [['Partial Controller Support', 'Steam Cloud']]       200        16
# 73341                                               [[]]        28        11
# 78274                          [['Steam Trading Cards']]        69         2
# 78722                                               [[]]        10         2
#
#                                                     tags  \
# 51271                             [Animation & Modeling]
# 58416  [Action, Hentai, Nudity, VR, Sexual Content, N...
# 64554  [Animation & Modeling, Game Development, 3D, D...
# 73341                       [Video Production, Software]
# 78274  [Video Production, Animation & Modeling, Desig...
# 78722  [Design & Illustration, Animation & Modeling, 3D]
#
#                                          tag_frequencies   app_id min_owners  \
# 51271                                               [24]   253670          0
# 58416  [88, 33, 26, 26, 24, 23, 21, 17, 17, 16, 12, 1...  1200520          0
# 64554                    [64, 60, 42, 39, 27, 22, 16, 7]   502570          0
# 73341                                           [34, 14]  2070990          0
# 78274                                   [33, 33, 32, 22]   438450          0
# 78722                                       [22, 21, 10]  1105450          0
#
#       max_owners
# 51271      20000
# 58416      20000
# 64554      20000
# 73341      20000
# 78274      20000
# 78722      20000

# %% [markdown]
# We can see that the game priced at $999 is basically a cash-grab without any actual sales, and being an extreme outlier it can distort our analysis. Let's remove it:

# %%
# Delete game with id 26936
df2 = df2[df2['app_id'] != 26936]

# %%
df2
# Out:
#                                   name release_date  price  \
# 1                  PUBG: BATTLEGROUNDS   2017-12-21   0.00
# 2                               Dota 2   2013-07-09   0.00
# 3                   Grand Theft Auto V   2015-04-13   0.00
# 4      Tom Clancy's Rainbow Six® Siege   2015-12-01  19.99
# 8                                 Rust   2018-02-08  39.99
# ...                                ...          ...    ...
# 83641                  Circuit Breaker   2021-10-21   4.99
# 83642                    Chess vs Chat   2022-08-09   3.99
# 83643                        Orbtangle   2022-10-28   1.99
# 83644                       Flashlight   2021-10-25   2.99
# 83645                         Wonfourn   2018-06-15   5.99
#
#                                        short_description  \
# 1      Play PUBG: BATTLEGROUNDS for free. Land on str...
# 2      Every day, millions of players worldwide enter...
# 3      Grand Theft Auto V for PC offers players the o...
# 4      Tom Clancy's Rainbow Six® Siege is an elite, t...
# 8      The only aim in Rust is to survive. Everything...
# ...                                                  ...
# 83641  In the cyber-future of 2009, the most popular ...
# 83642  Allow your chatters to actively participate an...
# 83643  Orbtangle is a simplistic puzzle game which re...
# 83644  Salvage scrap, build defenses, and rank-up to ...
# 83645  Wonfourn challenges you to fulfill your destin...
#
#                                               categories  positive  negative  \
# 1      [['Multi-player', 'PvP', 'Online PvP', 'Stats'...   1379580    981860
# 2      [['Multi-player', 'Co-op', 'Steam Trading Card...   1832477    406030
# 3      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1557234    236827
# 4      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1094330    190046
# 8      [['Multi-player', 'MMO', 'PvP', 'Online PvP', ...    922081    136729
# ...                                                  ...       ...       ...
# 83641              [['Single-player', 'Family Sharing']]         1         0
# 83642  [['Single-player', 'Multi-player', 'PvP', 'Onl...         2         1
# 83643  [['Single-player', 'Steam Achievements', 'Fami...         5         0
# 83644  [['Single-player', 'Multi-player', 'PvP', 'Onl...         3         0
# 83645  [['Single-player', 'Tracked Controller Support...         2        11
#
#                                                     tags  \
# 1      [Survival, Shooter, Battle Royale, Multiplayer...
# 2      [Free to Play, MOBA, Multiplayer, Strategy, e-...
# 3      [Open World, Action, Multiplayer, Crime, Autom...
# 4      [FPS, PvP, e-sports, Multiplayer, Tactical, Sh...
# 8      [Survival, Crafting, Multiplayer, Open World, ...
# ...                                                  ...
# 83641  [Strategy, Casual, PvE, Singleplayer, Tactical...
# 83642  [Indie, Strategy, Puzzle, Multiplayer, 2D, Che...
# 83643  [Puzzle, Colorful, Relaxing, Logic, Minimalist...
# 83644  [Top-Down Shooter, Rogue-lite, Action Roguelik...
# 83645  [Action, Indie, Violent, Strategy, Adventure, VR]
#
#                                          tag_frequencies   app_id min_owners  \
# 1      [14611, 12477, 10683, 10648, 8242, 7598, 7202,...   578080   50000000
# 2      [59559, 19966, 15153, 14096, 11631, 10822, 816...      570  200000000
# 3      [31998, 23177, 21328, 19059, 18579, 18412, 180...   271590   50000000
# 4      [9689, 9073, 9026, 8948, 8948, 8944, 8901, 888...   359550   20000000
# 8      [17867, 11333, 11263, 10699, 8363, 7973, 7266,...   252490   50000000
# ...                                                  ...      ...        ...
# 83641  [72, 48, 47, 44, 41, 37, 32, 29, 27, 25, 22, 2...  1745960          0
# 83642                   [31, 21, 11, 11, 11, 11, 11, 11]  1888920          0
# 83643  [54, 46, 44, 41, 38, 33, 30, 27, 25, 24, 22, 2...  2166420          0
# 83644  [138, 132, 128, 125, 121, 116, 108, 107, 104, ...  1456260          0
# 83645                           [22, 20, 20, 19, 19, 10]   655980          0
#
#       max_owners
# 1      100000000
# 2      500000000
# 3      100000000
# 4       50000000
# 8      100000000
# ...          ...
# 83641      20000
# 83642      20000
# 83643      20000
# 83644      20000
# 83645      20000
#
# [68206 rows x 12 columns]

# %% [markdown]
# ## Adding game length
#
# The second dataset we'll use contains information about game duration, submitted by users on the website [HowLongToBeat](https://howlongtobeat.com/). Let's load it and have a look:

# %%
second_file = 'steamdb.json'
df_extra = pd.read_json(second_file)

# %%
df_extra
# Out:
#            sid                                   store_url  \
# 0           10       https://store.steampowered.com/app/10
# 1           20       https://store.steampowered.com/app/20
# 2           30       https://store.steampowered.com/app/30
# 3           40       https://store.steampowered.com/app/40
# 4           50       https://store.steampowered.com/app/50
# ...        ...                                         ...
# 53976  1966310  https://store.steampowered.com/app/1966310
# 53977  1971880  https://store.steampowered.com/app/1971880
# 53978  1971980  https://store.steampowered.com/app/1971980
# 53979  1976030  https://store.steampowered.com/app/1976030
# 53980  1979280  https://store.steampowered.com/app/1979280
#
#                                    store_promo_url  store_uscore  \
# 0      https://www.youtube.com/watch?v=oKC9SAF4JAc          97.0
# 1                                             None          84.0
# 2      https://www.youtube.com/watch?v=j4MCo89bTWE          90.0
# 3      https://www.youtube.com/watch?v=jN_18uhiMS8          82.0
# 4      https://www.youtube.com/watch?v=ZNZsWm-Ulk4          95.0
# ...                                            ...           ...
# 53976                                         None           NaN
# 53977                                         None           NaN
# 53978                                         None           NaN
# 53979                                         None           NaN
# 53980                                         None           NaN
#
#       published_store published_meta published_stsp published_hltb  \
# 0          2000-11-01     2000-11-08     2000-11-01     1999-06-12
# 1          1999-04-01     1999-04-07     1999-04-01     1999-04-07
# 2          2003-05-01     2003-05-06     2003-05-01     2000-08-04
# 3          2001-06-01     2001-06-07     2001-06-01     2001-06-01
# 4          1999-11-01     1999-10-31     1999-11-01     1999-11-01
# ...               ...            ...            ...            ...
# 53976      2022-04-22           None           None           None
# 53977      2022-04-22           None           None     2016-12-09
# 53978      2022-04-21           None           None           None
# 53979      2022-04-24           None           None           None
# 53980      2022-04-26           None           None           None
#
#       published_igdb                                              image  ...  \
# 0         1999-06-12  https://steamcdn-a.akamaihd.net/steam/apps/10/...  ...
# 1         1999-04-07  https://steamcdn-a.akamaihd.net/steam/apps/20/...  ...
# 2         2003-05-01  https://steamcdn-a.akamaihd.net/steam/apps/30/...  ...
# 3         2001-07-01  https://steamcdn-a.akamaihd.net/steam/apps/40/...  ...
# 4         1999-11-10  https://steamcdn-a.akamaihd.net/steam/apps/50/...  ...
# ...              ...                                                ...  ...
# 53976           None  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 53977           None  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 53978           None  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 53979           None  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 53980           None  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
#
#                                                 meta_url meta_score  \
# 0      https://www.metacritic.com/game/pc/counter-str...       88.0
# 1      https://www.metacritic.com/game/pc/team-fortre...        NaN
# 2      https://www.metacritic.com/game/pc/day-of-defe...       79.0
# 3      https://www.metacritic.com/game/pc/deathmatch-...        NaN
# 4      https://www.metacritic.com/game/pc/half-life-o...        NaN
# ...                                                  ...        ...
# 53976                                               None        NaN
# 53977                                               None        NaN
# 53978                                               None        NaN
# 53979                                               None        NaN
# 53980                                               None        NaN
#
#        meta_uscore  grnk_score  \
# 0             92.0         NaN
# 1             71.0         NaN
# 2             91.0         NaN
# 3             68.0         NaN
# 4             86.0         NaN
# ...            ...         ...
# 53976          NaN         NaN
# 53977          NaN         NaN
# 53978          NaN         NaN
# 53979          NaN         NaN
# 53980          NaN         NaN
#
#                                                 igdb_url igdb_single  \
# 0              https://www.igdb.com/games/counter-strike         NaN
# 1       https://www.igdb.com/games/team-fortress-classic         NaN
# 2               https://www.igdb.com/games/day-of-defeat         NaN
# 3          https://www.igdb.com/games/deathmatch-classic         NaN
# 4      https://www.igdb.com/games/half-life-opposing-...         6.0
# ...                                                  ...         ...
# 53976                                               None         NaN
# 53977                                               None         NaN
# 53978                                               None         NaN
# 53979                                               None         NaN
# 53980                                               None         NaN
#
#       igdb_complete igdb_score igdb_uscore igdb_popularity
# 0               NaN       70.0        83.0           25.74
# 1               NaN        NaN        70.0            1.67
# 2               NaN       71.0        76.0            1.45
# 3               NaN        NaN        75.0            1.00
# 4               4.0       70.0        82.0            3.45
# ...             ...        ...         ...             ...
# 53976           NaN        NaN         NaN             NaN
# 53977           NaN        NaN         NaN             NaN
# 53978           NaN        NaN         NaN             NaN
# 53979           NaN        NaN         NaN             NaN
# 53980           NaN        NaN         NaN             NaN
#
# [53981 rows x 46 columns]

# %% [markdown]
# We're only interested in the column 'hltb_single', that contains the information on game length we need. Each Steam game has a unique identifier we can use to join the data from both datasets. This unique identifier is found in the column 'app_id' of the first dataset, and in the column 'sid' of the second dataset. First we'll have to convert 'app_id' to integer since it is currently an object. Let's join the data and see the result:

# %%
# Convert 'app_id' integer
df2['app_id'] = pd.to_numeric(df2['app_id'], errors='coerce').astype('Int64')

# Perform a left join for 'hltb_single'
df_merged = pd.merge(df2, df_extra[['sid', 'hltb_single']], left_on='app_id', right_on='sid', how='left')

# Drop the redundant 'sid' column
df_merged.drop('sid', axis=1, inplace=True)

# %%
df_merged
# Out:
#                                   name release_date  price  \
# 0                  PUBG: BATTLEGROUNDS   2017-12-21   0.00
# 1                               Dota 2   2013-07-09   0.00
# 2                   Grand Theft Auto V   2015-04-13   0.00
# 3      Tom Clancy's Rainbow Six® Siege   2015-12-01  19.99
# 4                                 Rust   2018-02-08  39.99
# ...                                ...          ...    ...
# 68201                  Circuit Breaker   2021-10-21   4.99
# 68202                    Chess vs Chat   2022-08-09   3.99
# 68203                        Orbtangle   2022-10-28   1.99
# 68204                       Flashlight   2021-10-25   2.99
# 68205                         Wonfourn   2018-06-15   5.99
#
#                                        short_description  \
# 0      Play PUBG: BATTLEGROUNDS for free. Land on str...
# 1      Every day, millions of players worldwide enter...
# 2      Grand Theft Auto V for PC offers players the o...
# 3      Tom Clancy's Rainbow Six® Siege is an elite, t...
# 4      The only aim in Rust is to survive. Everything...
# ...                                                  ...
# 68201  In the cyber-future of 2009, the most popular ...
# 68202  Allow your chatters to actively participate an...
# 68203  Orbtangle is a simplistic puzzle game which re...
# 68204  Salvage scrap, build defenses, and rank-up to ...
# 68205  Wonfourn challenges you to fulfill your destin...
#
#                                               categories  positive  negative  \
# 0      [['Multi-player', 'PvP', 'Online PvP', 'Stats'...   1379580    981860
# 1      [['Multi-player', 'Co-op', 'Steam Trading Card...   1832477    406030
# 2      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1557234    236827
# 3      [['Single-player', 'Multi-player', 'PvP', 'Onl...   1094330    190046
# 4      [['Multi-player', 'MMO', 'PvP', 'Online PvP', ...    922081    136729
# ...                                                  ...       ...       ...
# 68201              [['Single-player', 'Family Sharing']]         1         0
# 68202  [['Single-player', 'Multi-player', 'PvP', 'Onl...         2         1
# 68203  [['Single-player', 'Steam Achievements', 'Fami...         5         0
# 68204  [['Single-player', 'Multi-player', 'PvP', 'Onl...         3         0
# 68205  [['Single-player', 'Tracked Controller Support...         2        11
#
#                                                     tags  \
# 0      [Survival, Shooter, Battle Royale, Multiplayer...
# 1      [Free to Play, MOBA, Multiplayer, Strategy, e-...
# 2      [Open World, Action, Multiplayer, Crime, Autom...
# 3      [FPS, PvP, e-sports, Multiplayer, Tactical, Sh...
# 4      [Survival, Crafting, Multiplayer, Open World, ...
# ...                                                  ...
# 68201  [Strategy, Casual, PvE, Singleplayer, Tactical...
# 68202  [Indie, Strategy, Puzzle, Multiplayer, 2D, Che...
# 68203  [Puzzle, Colorful, Relaxing, Logic, Minimalist...
# 68204  [Top-Down Shooter, Rogue-lite, Action Roguelik...
# 68205  [Action, Indie, Violent, Strategy, Adventure, VR]
#
#                                          tag_frequencies   app_id min_owners  \
# 0      [14611, 12477, 10683, 10648, 8242, 7598, 7202,...   578080   50000000
# 1      [59559, 19966, 15153, 14096, 11631, 10822, 816...      570  200000000
# 2      [31998, 23177, 21328, 19059, 18579, 18412, 180...   271590   50000000
# 3      [9689, 9073, 9026, 8948, 8948, 8944, 8901, 888...   359550   20000000
# 4      [17867, 11333, 11263, 10699, 8363, 7973, 7266,...   252490   50000000
# ...                                                  ...      ...        ...
# 68201  [72, 48, 47, 44, 41, 37, 32, 29, 27, 25, 22, 2...  1745960          0
# 68202                   [31, 21, 11, 11, 11, 11, 11, 11]  1888920          0
# 68203  [54, 46, 44, 41, 38, 33, 30, 27, 25, 24, 22, 2...  2166420          0
# 68204  [138, 132, 128, 125, 121, 116, 108, 107, 104, ...  1456260          0
# 68205                           [22, 20, 20, 19, 19, 10]   655980          0
#
#       max_owners  hltb_single
# 0      100000000          NaN
# 1      500000000          NaN
# 2      100000000         31.0
# 3       50000000          NaN
# 4      100000000          NaN
# ...          ...          ...
# 68201      20000          NaN
# 68202      20000          NaN
# 68203      20000          NaN
# 68204      20000          NaN
# 68205      20000          NaN
#
# [68206 rows x 13 columns]

# %%
# Box plot of hltb_single
df_merged.boxplot(column=['hltb_single'])
# Out:
# <Axes: >

# %%
# Games with more than 500 hours of duration
df_merged[df_merged['hltb_single'] > 500]
# Out:
#                         name release_date  price  \
# 1047             Melvor Idle   2021-11-18   9.99
# 1065                NGU IDLE   2019-10-01   0.00
# 3773  Zombidle : REMONSTERED   2017-05-30   0.00
#
#                                       short_description  \
# 1047  Inspired by RuneScape, Melvor Idle takes the c...
# 1065  NGU Idle is a Free To Play Idle game that's fu...
# 3773  Like the song says, good guys finish last, and...
#
#                                              categories  positive  negative  \
# 1047  [['Single-player', 'Steam Achievements', 'Stea...     10852      1151
# 1065  [['Single-player', 'Steam Achievements', 'In-A...     10623       429
# 3773  [['Single-player', 'Cross-Platform Multiplayer...      1441       244
#
#                                                    tags  \
# 1047  [Idler, RPG, Casual, Indie, Singleplayer, Adve...
# 1065  [Free to Play, Idler, Indie, Clicker, Adventur...
# 3773  [Free to Play, Clicker, Casual, Indie, Zombies...
#
#                                         tag_frequencies   app_id min_owners  \
# 1047  [187, 138, 133, 117, 105, 104, 96, 95, 87, 86,...  1267910     500000
# 1065  [155, 133, 122, 90, 89, 77, 77, 51, 50, 49, 25...  1147690     500000
# 3773      [118, 88, 52, 49, 49, 42, 25, 25, 18, 10, 10]   612020     200000
#
#      max_owners  hltb_single
# 1047    1000000       4056.0
# 1065    1000000       5149.0
# 3773     500000        774.0

# %% [markdown]
# Some games are extreme outliers in terms of duration. This is not caused by these games being extremely long but by the fact that some games can be played indefinitely and very few users have reported game length for these types of games. This might distort our analysis, so we'll limit the maximum duration of games at 100 hours, which is a reasonable upper limit for most games:

# %%
# Limit game duration to 100 hours
df_merged['hltb_single'] = df_merged['hltb_single'].apply(lambda x: 100 if x > 100 else x)

# %% [markdown]
# ## Normalizing data
#
# The DataFrame contains fields such as 'categories' or 'tags' that consist on lists of values. To improve the performance of the visualization we'll build in Tableau we must convert this fields into separate tables, that will be linked with the main table using the 'app_id' column.

# %%
# Create a separate DataFrame for each list-type column
df_categories = df_merged.explode('categories')[['app_id', 'categories']]
df_tags = df_merged.explode('tags')[['app_id', 'tags']]
df_frequencies = df_merged.explode('tag_frequencies')['tag_frequencies']
df_tags['tag_frequencies'] = df_frequencies.values

# Remove the list columns from the main DataFrame
columns_to_remove = ['categories', 'tags', 'tag_frequencies']
df_imploded = df_merged.drop(columns=columns_to_remove)

# %%
df_imploded
# Out:
#                                   name release_date  price  \
# 0                  PUBG: BATTLEGROUNDS   2017-12-21   0.00
# 1                               Dota 2   2013-07-09   0.00
# 2                   Grand Theft Auto V   2015-04-13   0.00
# 3      Tom Clancy's Rainbow Six® Siege   2015-12-01  19.99
# 4                                 Rust   2018-02-08  39.99
# ...                                ...          ...    ...
# 68201                  Circuit Breaker   2021-10-21   4.99
# 68202                    Chess vs Chat   2022-08-09   3.99
# 68203                        Orbtangle   2022-10-28   1.99
# 68204                       Flashlight   2021-10-25   2.99
# 68205                         Wonfourn   2018-06-15   5.99
#
#                                        short_description  positive  negative  \
# 0      Play PUBG: BATTLEGROUNDS for free. Land on str...   1379580    981860
# 1      Every day, millions of players worldwide enter...   1832477    406030
# 2      Grand Theft Auto V for PC offers players the o...   1557234    236827
# 3      Tom Clancy's Rainbow Six® Siege is an elite, t...   1094330    190046
# 4      The only aim in Rust is to survive. Everything...    922081    136729
# ...                                                  ...       ...       ...
# 68201  In the cyber-future of 2009, the most popular ...         1         0
# 68202  Allow your chatters to actively participate an...         2         1
# 68203  Orbtangle is a simplistic puzzle game which re...         5         0
# 68204  Salvage scrap, build defenses, and rank-up to ...         3         0
# 68205  Wonfourn challenges you to fulfill your destin...         2        11
#
#         app_id min_owners max_owners  hltb_single
# 0       578080   50000000  100000000          NaN
# 1          570  200000000  500000000          NaN
# 2       271590   50000000  100000000         31.0
# 3       359550   20000000   50000000          NaN
# 4       252490   50000000  100000000          NaN
# ...        ...        ...        ...          ...
# 68201  1745960          0      20000          NaN
# 68202  1888920          0      20000          NaN
# 68203  2166420          0      20000          NaN
# 68204  1456260          0      20000          NaN
# 68205   655980          0      20000          NaN
#
# [68206 rows x 10 columns]

# %% [markdown]
# The main DataFrame is ready. Since the goal of the dashboard I want to build is to filter data by tags or categories and view their most relevant metrics, I'll remove any categories and tags with less than 50 games, since they are not relevant enough:

# %%
# Filter out categories with less than 50 games
categories_counts = df_categories['categories'].value_counts()
categories_to_keep = categories_counts[categories_counts >= 50].index.tolist()
df_categories = df_categories[df_categories['categories'].isin(categories_to_keep)]

# %%
df_categories
# Out:
#         app_id                    categories
# 0       578080               ['Multi-player'
# 0       578080                         'PvP'
# 0       578080                  'Online PvP'
# 0       578080                       'Stats'
# 0       578080        'Remote Play on Phone'
# ...        ...                           ...
# 68204  1456260             'Family Sharing']
# 68205   655980              ['Single-player'
# 68205   655980  'Tracked Controller Support'
# 68205   655980                     'VR Only'
# 68205   655980             'Family Sharing']
#
# [301762 rows x 2 columns]

# %%
# Filter out tags with less than 50 games
tags_counts = df_tags['tags'].value_counts()
tags_to_keep = tags_counts[tags_counts >= 50].index.tolist()
df_tags = df_tags[df_tags['tags'].isin(tags_to_keep)]

# %%
df_tags
# Out:
#        app_id           tags tag_frequencies
# 0      578080       Survival           14611
# 0      578080        Shooter           12477
# 0      578080  Battle Royale           10683
# 0      578080    Multiplayer           10648
# 0      578080            FPS            8242
# ...       ...            ...             ...
# 68205  655980          Indie              20
# 68205  655980        Violent              20
# 68205  655980       Strategy              19
# 68205  655980      Adventure              19
# 68205  655980             VR              10
#
# [920900 rows x 3 columns]

# %% [markdown]
# ## Save results as CSV
#
# Finally, we'll save the results as CSV files that we'll import into Tableau:

# %%
df_imploded.to_csv('tableau_games.csv', index=False)
df_categories.to_csv('tableau_categories.csv', index=False)
df_tags.to_csv('tableau_tags.csv', index=False)

# %% [markdown]
# ## View the Dashboard
#
# Head out to Tableau public to see the dashboard I created with this data:
#
# [Steam Tag Explorer](https://public.tableau.com/app/profile/terencicp/viz/steam-games/Dash)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tableau_games.csv', encoding='utf-8')

# %%
df.isnull().sum()
# Out:
# App_ID                 0
# Game_Name            773
# Release_Date           0
# Price                  0
# Short_Description    337
# Positive               0
# Negative               0
# Min_Owners             0
# Max_Owners             0
# HLTB_Single            0
# dtype: int64

# %%
# Replace missing 'short_description' with "No Description Available"
df['Short_Description'] = df['Short_Description'].fillna("No Description Available")

# %%
df.isnull().sum()
# Out:
# App_ID                 0
# Game_Name            773
# Release_Date           0
# Price                  0
# Short_Description      0
# Positive               0
# Negative               0
# Min_Owners             0
# Max_Owners             0
# HLTB_Single            0
# dtype: int64

# %%
df = df.dropna(subset=['Game_Name'])

# %%
df.isnull().sum()
# Out:
# App_ID               0
# Game_Name            0
# Release_Date         0
# Price                0
# Short_Description    0
# Positive             0
# Negative             0
# Min_Owners           0
# Max_Owners           0
# HLTB_Single          0
# dtype: int64

# %%
df.to_csv('tableau_games1.csv', index=False)

# %%
# Load the main CSV file (after dropping null values)
df_main = pd.read_csv('tableau_games.csv')

# Load the two other CSV files that also contain 'App_ID'
df_other1 = pd.read_csv('tableau_tags.csv')
df_other2 = pd.read_csv('tableau_categories.csv')

# Identify app_ids present in the updated main file
existing_app_ids = df_main['App_ID'].tolist()

# Filter the other files based on those app_ids
df_other1_filtered = df_other1[df_other1['App_ID'].isin(existing_app_ids)]
df_other2_filtered = df_other2[df_other2['App_ID'].isin(existing_app_ids)]

# Save the filtered CSVs
df_other1_filtered.to_csv('tableau_tags_filtered.csv', index=False)
df_other2_filtered.to_csv('tableau_categories_filtered.csv', index=False)

# Verify the changes
print("Remaining rows in tableau_tags.csv:", len(df_other1_filtered))
print("Remaining rows in tableau_categories.csv:", len(df_other2_filtered))
# Out:
# Remaining rows in tableau_tags.csv: 910623
# Remaining rows in tableau_categories.csv: 299597

# %%
df = pd.read_csv('csv_categories.csv', encoding='utf-8')

# %%
df.isnull().sum()
# Out:
# App_ID        0
# Categories    0
# dtype: int64

# %%
df = df.dropna(subset=['Categories'])

# %%
df.to_csv('csv_categories1.csv', index=False)
